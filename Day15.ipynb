# %% [markdown]
# <h1 style="font-size:50px; color:red">tuple</h1>

# %% [markdown]
# <h1>tuples are read-only datatype</h1>

# %%
t = ()
type(t)
# Out:
# tuple

# %%
t=(1,2,3)
t
# Out:
# (1, 2, 3)

# %%
t = ("hello",3.5,1)
t
# Out:
# ('hello', 3.5, 1)

# %%
t = (1,2,3,(4,5))
t
# Out:
# (1, 2, 3, (4, 5))

# %%
t = (1)
type(t)
# Out:
# int

# %%
t = (1,)
type(t)
# Out:
# tuple

# %%
t = ("tushar")
t
# Out:
# 'tushar'

# %%
type(t)
# Out:
# str

# %%
t = tuple('tushar')

# %%
t
# Out:
# ('t', 'u', 's', 'h', 'a', 'r')

# %%
t = tuple([1,2,3,4,5])
t
# Out:
# (1, 2, 3, 4, 5)

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# <h1 style="font-size:30px; color:blue">ACCESSING</h1>

# %%
t = (1,2,3)
t[0]
# Out:
# 1

# %%
t[:]
# Out:
# (1, 2, 3)

# %%
t[-1]
# Out:
# 3

# %%
t[:]
# Out:
# (1, 2, 3)

# %%
t=(1,2,3,(4,5))
t[-1][0]
# Out:
# 4

# %% [markdown]
# <h1 style="font-size:30px; color:blue">EDITING</h1>

# %%
l = (1,2,3)
l[0]=3 # this will give you error because it is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_20697/1089665509.py in <module>
#       1 l = (1,2,3)
# ----> 2 l[0]=3 # this will give you error because it is immutable
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# <h1 style="font-size:30px; color:BLUE">DELETION</h1>

# %%
t = (1,2,3)
del t[0] # tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_20697/1534924880.py in <module>
#       1 t = (1,2,3)
# ----> 2 del t[0] # tuples are immutable
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
del t #you can delete the whole tuple but you can't change by deleting perticular element from tuple

# %% [markdown]
# <h1 style="font-size:30px; color:blue">Operations</h1>

# %%
(1,2,3)+(4,5,6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
(1,2,3)*3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
for i in (1,2,3):
    print(i,end=' ')
# Out:
# 1 2 3

# %% [markdown]
# <h1 style="font-size:30px; color:blue">Functions</h1>

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">len()</h1>

# %%
len((1,2,3))
# Out:
# 3

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">min()</h1>

# %%
min((1,2,3))
# Out:
# 1

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">max()</h1>

# %%
max((1,2,4))
# Out:
# 4

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">sum()</h1>

# %%
sum((1,2,3))
# Out:
# 6

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">sorted()</h1>

# %%
sorted((3,2,1))
# Out:
# [1, 2, 3]

# %%
sorted((1,2,3),reverse=True)
# Out:
# [3, 2, 1]
