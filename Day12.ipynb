# %% [markdown]
# <h1 style="font-size:50px; color:red">Module</h1>

# %% [markdown]
# A file containing a set of functions you want to include in your application.
# Examples of python modules
# <ul>
# <li>math</li>
# <li>random</li>
# <li>os</li>
# <li>time</li>
# </ul>

# %%
#this will give you list of all modules
# help('modules')

# %% [markdown]
# <h1 style="font-size:30px; color:blue">1. math</h1>

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(5)
# Out:
# 120

# %%
math.ceil(8.9)
# Out:
# 9

# %%
math.floor(8.9)
# Out:
# 8

# %%
math.nan
# Out:
# nan

# %%
math.sqrt(100)
# Out:
# 10.0

# %% [markdown]
# <h1 style="font-size:30px; color:blue">2. random</h1>

# %%
import random

# %%
random.randint(1,20)
# this will give you random no. b/w giving range
# Out:
# 9

# %%
random.random()
# Out:
# 0.5028472472465623

# %%
a = [1,2,3,4,5]
random.shuffle(a) # this will shuffle your list
a
# Out:
# [2, 4, 3, 5, 1]

# %% [markdown]
# <h1 style="font-size:30px; color:blue">3. time</h1>

# %%
import time

# %%
time.time()
# Out:
# 1685175157.389142

# %%
time.ctime() # this will tell you current time
# Out:
# 'Sat Mar  9 16:16:04 2024'

# %%
print("hello")
time.sleep(10)
print("world")
# Out:
# hello
# world

# %% [markdown]
# <h1 style="font-size:30px; color:blue">4. os</h1>

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/anurag10/100_days_Of_python'

# %%
os.listdir()
# Out:
# ['Day16.ipynb',
#  'flipkart-icon.png',
#  'Day13.ipynb',
#  'PuneetPractice file.ipynb',
#  'Day11.ipynb',
#  'Day25.ipynb',
#  'Day2.ipynb',
#  'Day12.ipynb',
#  'Day18.ipynb',
#  'Day17.ipynb',
#  'Day21.ipynb',
#  '.git',
#  'Day24.ipynb',
#  'Day22.ipynb',
#  'Day20.ipynb',
#  '.ipynb_checkpoints',
#  'Day27.ipynb',
#  'Day14.ipynb',
#  'Day8.ipynb',
#  'Day23.ipynb',
#  'Day6.ipynb',
#  'Day1.ipynb',
#  'Day10.ipynb',
#  'Day4.ipynb',
#  'Day15.ipynb',
#  'Day9.ipynb',
#  'Day7.ipynb',
#  'Day3.ipynb',
#  'Day5.ipynb',
#  'wallpapers',
#  'Day26.ipynb',
#  'Day19.ipynb']
