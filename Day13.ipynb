# %% [markdown]
# <h1 style="font-size:50px; color:red">String</h1>

# %% [markdown]
# Strings are sequence of Characters
#
# In python specifically, string are a sequence of Unicode Character
# <ul>
# <li>Creating Strings</li>
# <li>Accessing Strings</li>
# <li>Adding Chars to Strings</li>
# <li>Editing Strings</li>
# <li>Deleting Strings</li>
# <li>Operations on Strings</li>
# <li>String Functions</li>
# </ul>

# %% [markdown]
# <h1 style="font-size:30px; color:blue">CREATING</h1>

# %%
c = 'hello'
print(c)
# Out:
# hello

# %%
c = "hello"
print(c)
# Out:
# hello

# %%
# multiline string
c = """hi""" 
c
# Out:
# 'hi'

# %%
c = str(" tushar")
print(c)
# Out:
#  tushar

# %% [markdown]
# <h1 style="font-size:30px; color:blue">ACCESSING</h1>

# %%
#CONCEPT OF INDEXING

# %%
c = "hello"
print(c[0])
# Out:
# h

# %%
print(c[3])
# Out:
# l

# %%
#type of indexing
# positive indexing
# negative indexing

# %%
print(c[-1])
# Out:
# o

# %%
c[-2]
# Out:
# 'l'

# %%
c[-3]
# Out:
# 'l'

# %%
c[-4]
# Out:
# 'e'

# %%
c[-5]
# Out:
# 'h'

# %% [markdown]
# # CONCEPT OF SLICING

# %%
c = "Hello world"
c[0:4]
# Out:
# 'Hell'

# %%
c[0:3]
# Out:
# 'Hel'

# %%
c[2:]
# Out:
# 'llo world'

# %%
c[:]
# Out:
# 'Hello world'

# %%
c[:4]
# Out:
# 'Hell'

# %%
c[2:6:2]
# Out:
# 'lo'

# %%
c[-5:-1:2]
# Out:
# 'wr'

# %%
c[::-1]
# Out:
# 'dlrow olleH'

# %% [markdown]
# <h1 style="font-size:30px; color:blue">EDITING AND DELETING</h1>

# %%
c = "hello"
print(c)
# Out:
# hello

# %%
c[0] = 'X' # this will give error because strings are Immutable Data type
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8219/2473887928.py in <module>
# ----> 1 c[0] = 'X' # this will give error because strings are Immutable Data type
#
# TypeError: 'str' object does not support item assignment

# %%
c = "world"

# %%
# deletion
del c

# %%
c #because we already delete string 'c' using del keyword
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8219/1121910082.py in <module>
# ----> 1 c #because we already delete string 'c' using del keyword
#
# NameError: name 'c' is not defined

# %%
c = 'hello'

# %%
del c[0] # because strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8219/2158837504.py in <module>
# ----> 1 del c[0] # because strings are immutable
#
# TypeError: 'str' object doesn't support item deletion

# %% [markdown]
# <h1 style="font-size:30px; color:blue">Operations</h1>

# %% [markdown]
# <ul>
# <li> Arithmetic Operations</li>
# <li>Relational Operations</li>
# <li>Logical Operations</li>
# <li>Loops on Strings</li>
# <li>Membership Operations</li>
# </ul>

# %% [markdown]
# # Arithmetic Operations

# %%
"hello"+" world" # concatination
# Out:
# 'hello world'

# %%
print("*"*50)
# Out:
# **************************************************

# %% [markdown]
# # Relational Operations

# %%
"Hello" == "Hello"
# Out:
# True

# %%
"Hello" != "world"
# Out:
# True

# %%
"Mumbai" > "pune" #lexiographically
# Out:
# False

# %%
"Koi" < "koi"
# Out:
# True

# %% [markdown]
# # Logical Operations

# %%
"hello" and "world"
# Out:
# 'world'

# %% [markdown]
# ### In python every empty string is false and not empty string is True

# %%
"hi" and ""
# Out:
# ''

# %%
"" or "world"
# Out:
# 'world'

# %%
"world" or ""
# Out:
# 'world'

# %%
not "hello"
# Out:
# False

# %%
not ""
# Out:
# True

# %% [markdown]
# # Loops on Strings

# %%
c ="hello world"
for i in c:
    print(i,end=' ')
# Out:
# h e l l o   w o r l d

# %%
for i in c[::-1]:
    print(i,end=" ")
# Out:
# d l r o w   o l l e h

# %% [markdown]
# # Membership Operations

# %%
c = "hello"
'h' in c
# Out:
# True

# %%
'e' in c
# Out:
# True

# %%
'w' in c
# Out:
# False

# %%
'w' not in c
# Out:
# True

# %%
'h' not in c
# Out:
# False

# %%
'hello' in c
# Out:
# True

# %% [markdown]
# <h1 style="font-size:30px; color:blue">Functions</h1>

# %% [markdown]
# common functions
# <ul>
# <li>len</li>
#     <li>max</li>
#     <li>min</li>
#     <li>sorted</li>
# </ul>

# %%
c = "kolkata"
len(c)
# Out:
# 7

# %%
max(c)
# Out:
# 't'

# %%
min(c)
# Out:
# 'a'

# %%
sorted(c)
# Out:
# ['a', 'a', 'k', 'k', 'l', 'o', 't']

# %%
sorted(c,reverse=True)
# Out:
# ['t', 'o', 'l', 'k', 'k', 'a', 'a']

# %% [markdown]
# # Methods

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">capitalize()</h1>

# %%
c.capitalize()
# Out:
# 'Kolkata'

# %%
"hi tushar".capitalize()
# Out:
# 'Hi tushar'

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">title()</h1>

# %%
c.title()
# Out:
# 'Kolkata'

# %%
"hi tushar".title()
# Out:
# 'Hi Tushar'

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">upper()</h1>

# %%
c.upper()
# Out:
# 'KOLKATA'

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">lower()</h1>

# %%
c.lower()
# Out:
# 'kolkata'

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">swapcase()</h1>

# %%
c.swapcase() #lower to upper and upper to lower
# Out:
# 'KOLKATA'

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">count()</h1>

# %%
"Hello world".count("i")
# Out:
# 0

# %%
"Hello world".count("e")
# Out:
# 1

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">find()</h1>

# %%
"hello".find('l') #this function will return first occurence of character
# Out:
# 2

# %%
"hello".find('x')
# Out:
# -1

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">index()</h1>

# %%
"hello".index('e')
# Out:
# 1

# %%
"hello".index('z') #this function will return error when a perticular element not present in string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8219/3387842398.py in <module>
# ----> 1 "hello".index('z') #this function will return error when a perticular element not present in string
#
# ValueError: substring not found

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">endswith()</h1>

# %%
"hello".endswith('h')
# Out:
# False

# %%
"hello".endswith('o')
# Out:
# True

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">startswith()</h1>

# %%
"hello".startswith('h')
# Out:
# True

# %%
"hello".startswith('o')
# Out:
# False

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">format()</h1>

# %%
"abhi is good boy"
# Out:
# 'abhi is good boy'

# %%
"{} is good {}".format("Tushar","Boy")
# Out:
# 'Tushar is good Boy'

# %%
"{1} is good {0}".format("Tushar","Boy")
# Out:
# 'Boy is good Tushar'

# %%
"{name} is good {gender}".format(name = "Tushar",gender = "Boy")
# Out:
# 'Tushar is good Boy'

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">isalnum()</h1>

# %%
"flat20".isalnum()
# Out:
# True

# %%
"flat20@".isalnum()
# Out:
# False

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">isalpha()</h1>

# %%
"flat".isalpha()
# Out:
# True

# %%
"flat20".isalpha()
# Out:
# False

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">isdigit()</h1>

# %%
"Hello".isdigit()
# Out:
# False

# %%
"hello1".isdigit()
# Out:
# False

# %%
"12".isdigit()
# Out:
# True

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">isidentifier()</h1>

# %%
"hello world".isidentifier()
# Out:
# False

# %%
"hello".isidentifier()
# Out:
# True

# %%
"hello_world".isidentifier()
# Out:
# True

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">isascii()</h1>

# %%
"23".isascii()
# Out:
# True

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">isdecimal()</h1>

# %%
"1.2".isdecimal()
# Out:
# False

# %%
"1".isdecimal()
# Out:
# True

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">islower()</h1>

# %%
"tushar".islower()
# Out:
# True

# %%
"Tushar".islower()
# Out:
# False

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">isupper()</h1>

# %%
"Tushar".isupper()
# Out:
# False

# %%
"tushar".isupper()
# Out:
# False

# %%
"TUSHAR".isupper()
# Out:
# True

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">split()</h1>

# %%
"who is the prime minister of india".split(' ')
# Out:
# ['who', 'is', 'the', 'prime', 'minister', 'of', 'india']

# %%
list("ansh")
# Out:
# ['a', 'n', 's', 'h']

# %%
"tushar".split()
# Out:
# ['tushar']

# %%
"who is the prime minister of india".split("prime minister")
# Out:
# ['who is the ', ' of india']

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">join()</h1>

# %%
" ".join(['who', 'is', 'the', 'prime', 'minister', 'of', 'india'])
# Out:
# 'who is the prime minister of india'

# %%
"- -".join(['who', 'is', 'the', 'prime', 'minister', 'of', 'india'])
# Out:
# 'who- -is- -the- -prime- -minister- -of- -india'

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">replace()</h1>

# %%
"Hi my name is Nitish".replace("Nitish","tushar")
# Out:
# 'Hi my name is tushar'

# %% [markdown]
# <h1 style="font-size:25px; color: #E48400">strip()</h1>

# %%
name = "          my name is tushar gupta"
print(name)
name = name.strip()
print(name)
# Out:
#           my name is tushar gupta
# my name is tushar gupta
